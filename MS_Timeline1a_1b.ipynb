# %% [markdown]
# # Timeline
# ## Positive Cases (NC x USA)
# ## Testing (NC x USA)

# %%
# %matplotlib notebook

# %%
#Dependencies and Setup
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cbook as cbook
import matplotlib.dates as mdates

# %%
#Reading CSV
us_and_nc_df = pd.read_csv("Resources/US_NC_Combined.csv")
us_and_nc_df.head()
# Out:
#    Unnamed: 0        date  US Population  US Deaths  US DeathIncrease  \
# 0           0  2021-03-07      332031554   515151.0               842
# 1           1  2021-03-06      332031554   514309.0              1680
# 2           2  2021-03-05      332031554   512629.0              2221
# 3           3  2021-03-04      332031554   510408.0              1743
# 4           4  2021-03-03      332031554   508665.0              2449
#
#    US inICUCumulative  US inICUCurrently  US HospitalizedIncrease  \
# 0             45475.0             8134.0                      726
# 1             45453.0             8409.0                      503
# 2             45373.0             8634.0                     2781
# 3             45293.0             8970.0                     1530
# 4             45214.0             9359.0                     2172
#
#    US HospitalizedCurrently  US HospitalizedCumulative  ...  \
# 0                   40199.0                   776361.0  ...
# ...

# %%
# Listing all th columns:
list(us_and_nc_df)
# Out:
# ['Unnamed: 0',
#  'date',
#  'US Population',
#  'US Deaths',
#  'US DeathIncrease',
#  'US inICUCumulative',
#  'US inICUCurrently',
#  'US HospitalizedIncrease',
#  'US HospitalizedCurrently',
#  'US HospitalizedCumulative',
#  'US Negative',
#  'US NegativeIncrease',
#  'US OnVentilatorCumulative',
#  'US OnVentilatorCurrently',
#  'US Positive',
#  'US PositiveIncrease',
#  'US TotalTestResults',
#  'US TotalTestResultsIncrease',
#  'NC Population',
#  'NC death',
#  'NC DeathIncrease',
#  'NC HospitalizedCumulative',
#  'NC HospitalizedCurrently',
#  'NC HospitalizedIncrease',
#  'NC InIcuCumulative',
#  'NC InIcuCurrently',
#  'NC Negative',
#  'NC NegativeIncrease',
#  'NC OnVentilatorCumulative',
#  'NC OnVentilatorCurrently',
#  'NC Positive',
#  'NC PositiveIncrease',
#  'NC TotalTestResults',
#  'NC TotalTestResultsIncrease']

# %%
#Copying original DF
positivecases_tests_df = us_and_nc_df.copy()
del positivecases_tests_df['Unnamed: 0']
list(positivecases_tests_df)
# Out:
# ['date',
#  'US Population',
#  'US Deaths',
#  'US DeathIncrease',
#  'US inICUCumulative',
#  'US inICUCurrently',
#  'US HospitalizedIncrease',
#  'US HospitalizedCurrently',
#  'US HospitalizedCumulative',
#  'US Negative',
#  'US NegativeIncrease',
#  'US OnVentilatorCumulative',
#  'US OnVentilatorCurrently',
#  'US Positive',
#  'US PositiveIncrease',
#  'US TotalTestResults',
#  'US TotalTestResultsIncrease',
#  'NC Population',
#  'NC death',
#  'NC DeathIncrease',
#  'NC HospitalizedCumulative',
#  'NC HospitalizedCurrently',
#  'NC HospitalizedIncrease',
#  'NC InIcuCumulative',
#  'NC InIcuCurrently',
#  'NC Negative',
#  'NC NegativeIncrease',
#  'NC OnVentilatorCumulative',
#  'NC OnVentilatorCurrently',
#  'NC Positive',
#  'NC PositiveIncrease',
#  'NC TotalTestResults',
#  'NC TotalTestResultsIncrease']

# %%
#Cleaning DF
positivecases_tests_df = positivecases_tests_df.drop(columns = ['US DeathIncrease',
                                       'US inICUCumulative',
                                       'US inICUCurrently',
                                       'US HospitalizedIncrease',
                                       'US HospitalizedCurrently',
                                       'US HospitalizedCumulative',
                                       'US Negative',
                                       'US NegativeIncrease',
                                       'US OnVentilatorCumulative',
                                       'US OnVentilatorCurrently',
                                       'NC DeathIncrease',
                                       'NC HospitalizedCumulative',
                                       'NC HospitalizedCurrently',
                                       'NC HospitalizedIncrease',
                                       'NC InIcuCumulative',
                                       'NC InIcuCurrently',
                                       'NC Negative',
                                       'NC NegativeIncrease',
                                       'NC OnVentilatorCumulative',
                                       'NC OnVentilatorCurrently',])

list(positivecases_tests_df)
# Out:
# ['date',
#  'US Population',
#  'US Deaths',
#  'US Positive',
#  'US PositiveIncrease',
#  'US TotalTestResults',
#  'US TotalTestResultsIncrease',
#  'NC Population',
#  'NC death',
#  'NC Positive',
#  'NC PositiveIncrease',
#  'NC TotalTestResults',
#  'NC TotalTestResultsIncrease']

# %%
#positivecases_tests_df = positivecases_tests_df.set_index("date")

# %%
positivecases_tests_df
positivecases_tests_df.dropna()
# Out:
#            date  US Population  US Deaths  US Positive  US PositiveIncrease  \
# 0    2021-03-07      332031554   515151.0   28756489.0                41835
# 1    2021-03-06      332031554   514309.0   28714654.0                60015
# 2    2021-03-05      332031554   512629.0   28654639.0                68787
# 3    2021-03-04      332031554   510408.0   28585852.0                65487
# 4    2021-03-03      332031554   508665.0   28520365.0                66836
# ..          ...            ...        ...          ...                  ...
# 364  2020-03-08      331511512       31.0        757.0                  170
# 365  2020-03-07      331511512       27.0        587.0                  142
# 366  2020-03-06      331511512       26.0        445.0                  138
# 367  2020-03-05      331511512       20.0        307.0                   65
# 368  2020-03-04      331511512       16.0        242.0                  128
#
# ...

# %%
# Calculating ration of Positive Cases in NC vs USA
positivecases_tests_df["NC_positive_cases"] = (positivecases_tests_df["NC Positive"]/positivecases_tests_df["NC Population"])*100000
positivecases_tests_df["USA_positive_cases"] = (positivecases_tests_df["US Positive"]/positivecases_tests_df["US Population"])*100000
positivecases_tests_df["NC_positive_cases"].dropna()
positivecases_tests_df["USA_positive_cases"].dropna()
# Out:
# 0      8660.769934
# 1      8648.170228
# 2      8630.095138
# 3      8609.378132
# 4      8589.655006
#           ...
# 415       0.000000
# 416       0.000000
# 417       0.000000
# 418       0.000000
# 419       0.000000
# Name: USA_positive_cases, Length: 420, dtype: float64

# %%
#Formating Date for charting
positivecases_tests_df["date"] = pd.to_datetime(positivecases_tests_df["date"], format='%Y-%m-%d')

# %%
#Saving the new DF
positivecases_tests_df.to_csv("Resources/positivecases_tests.csv", index = False)

# %%
#Plotting the graphs

#POSITIVE CASES - NC X USA
plt.figure(1)
plt.plot(positivecases_tests_df["date"], positivecases_tests_df["NC_positive_cases"], color= "blue", label ="NC")
plt.plot(positivecases_tests_df["date"], positivecases_tests_df["USA_positive_cases"], color = "red", label="USA")

# Create a legend for our chart
plt.legend(loc="best")
plt.title("Positive Cases (NC vs USA)")
plt.xlabel("Date")
plt.ylabel("Positive Cases per Capta")
plt.xticks(rotation=90, fontsize="small")
plt.yticks(fontsize="small")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### **Although NC and the USA have had similar behavior of positive cases of COVID-19, NC was always under the national ratio during the whole period.

# %%
positivecases_tests_df["NC_testing"] = positivecases_tests_df["NC TotalTestResults"]/positivecases_tests_df["NC Population"]*100000
positivecases_tests_df["USA_testing"] = positivecases_tests_df["US TotalTestResults"]/positivecases_tests_df["US Population"]*100000
positivecases_tests_df["NC_testing"].dropna()
positivecases_tests_df["USA_testing"].dropna()
# Out:
# 0      109575.466132
# 1      109223.072214
# 2      108792.091489
# 3      108266.714615
# 4      107787.548108
#            ...
# 415         0.000000
# 416         0.000000
# 417         0.000000
# 418         0.000000
# 419         0.000000
# Name: USA_testing, Length: 420, dtype: float64

# %%
# TESTS RATIO - NC X USA
plt.figure(2)
plt.plot(positivecases_tests_df["date"], positivecases_tests_df["NC_testing"], color= "blue", label ="NC")
plt.plot(positivecases_tests_df["date"], positivecases_tests_df["USA_testing"], color = "red", label="USA")

# Create a legend for our chart
plt.legend(loc="best")
plt.title("Tests per Capta (NC vs USA)")
plt.xlabel("Date")
plt.ylabel("Tested")
plt.xticks(rotation=90, fontsize="small")
plt.yticks(fontsize="small")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### ** When we compare the test rates between NC and the USA, it is possible to identify the same trend. However, NC was under the national test rates.
